# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
import statistics
from scipy.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
#data.describe()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %% [markdown]
# 1. Нормальное распределение - RM
# 2. Равномерное - нет
# 3. Биноминальное - нет
# 4. Бернулли - CHAS
# 5. Геометрическое - CRIM
# 6. Логнормальное - DIS

# %%
sns.distplot(data['CRIM'])
plt.show()

# %%
plt.hist(data['ZN'], 10)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['INDUS'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['CHAS'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['NOX'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['RM'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['AGE'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['DIS'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['RAD'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['TAX'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['PTRATIO'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['B'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['LSTAT'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
plt.hist(data['MEDV'], 20)
plt.xlabel('Значения')
plt.ylabel('Количество элементов')
plt.show()

# %%
# Напишите код, который будет рисовать распределения попарно - точечные распределение
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Загрузить таблицу Happiness report. Нарисовать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  ...  Log of GDP\nper capita  Healthy life\nexpectancy
# 0          Finland       1  ...                    22.0                      27.0
# 1          Denmark       2  ...                    14.0                      23.0
# 2           Norway       3  ...                     7.0                      12.0
# 3          Iceland       4  ...                    15.0                      13.0
# 4      Netherlands       5  ...                    12.0                      18.0
#
# [5 rows x 11 columns]

# %% [markdown]
# **Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.**

# %%
print(data.isnull().sum())
# в выборке country нет отсутствующих значений
# Out:
# Country (region)            0
# Ladder                      0
# SD of Ladder                0
# Positive affect             1
# Negative affect             1
# Social support              1
# Freedom                     1
# Corruption                  8
# Generosity                  1
# Log of GDP\nper capita      4
# Healthy life\nexpectancy    6
# dtype: int64

# %% [markdown]
# **Сколько стран в выборке? Написать ответ. Можно ли сказать, что данные значения - это проблема классификации?**

# %%
print(len(list(data['Country (region)'].unique())))
# всего 156 стран
# проблема в том, что в датасете представлены не все страны мира? некоторые страны на попарном графике (ниже) находятся довольно кучно
# Out:
# 156

# %% [markdown]
# **Матрица ковариаций попарно**

# %%
x = data.iloc[:, 1:].dropna()

standardized = (x - x.mean()) / x.std()
np.around(np.cov(standardized.T), decimals=2)
# Out:
# array([[1.  , 0.56, 0.51, 0.54, 0.83, 0.55, 0.22, 0.49, 0.82, 0.83],
#        [0.56, 1.  , 0.09, 0.63, 0.6 , 0.25, 0.25, 0.39, 0.66, 0.64],
#        [0.51, 0.09, 1.  , 0.35, 0.43, 0.7 , 0.23, 0.42, 0.31, 0.34],
#        [0.54, 0.63, 0.35, 1.  , 0.67, 0.42, 0.17, 0.35, 0.57, 0.51],
#        [0.83, 0.6 , 0.43, 0.67, 1.  , 0.48, 0.15, 0.45, 0.8 , 0.76],
#        [0.55, 0.25, 0.7 , 0.42, 0.48, 1.  , 0.41, 0.5 , 0.39, 0.42],
#        [0.22, 0.25, 0.23, 0.17, 0.15, 0.41, 1.  , 0.28, 0.19, 0.15],
#        [0.49, 0.39, 0.42, 0.35, 0.45, 0.5 , 0.28, 1.  , 0.46, 0.45],
#        [0.82, 0.66, 0.31, 0.57, 0.8 , 0.39, 0.19, 0.46, 1.  , 0.87],
#        [0.83, 0.64, 0.34, 0.51, 0.76, 0.42, 0.15, 0.45, 0.87, 1.  ]])

# %% [markdown]
# **Нарисовать sns.pairplot для класс - страна. Из графика сделать вывод о том, какие страны похожи.**

# %%
# Если код ниже не работает, измените код, используя материал лекций. Пишите на почту, если испытываете проблемы: yustiks@gmail.com

data_2 = data.dropna()
print(data_2.shape)

sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data=data_2[:], hue='Country (region)')
plt.show()
# Out:
# (140, 11)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# больше других похожи страны, находящиеся в скандинавском и африканском регионах, остальные более различаются по параметрам

# %% [markdown]
# **Посчитать матрицу корреляций для таблицы. Написать код. Сделать график. Какие можно сделать выводы?**

# %%
x.corr()
# Out:
#                             Ladder  ...  Healthy life\nexpectancy
# Ladder                    1.000000  ...                  0.826677
# SD of Ladder              0.555987  ...                  0.637554
# Positive affect           0.511870  ...                  0.339032
# Negative affect           0.539677  ...                  0.507148
# Social support            0.833412  ...                  0.755292
# Freedom                   0.546414  ...                  0.423949
# Corruption                0.224394  ...                  0.148973
# Generosity                0.485704  ...                  0.453135
# Log of GDP\nper capita    0.820608  ...                  0.873628
# Healthy life\nexpectancy  0.826677  ...                  1.000000
#
# [10 rows x 10 columns]

# %%
sns.heatmap(x.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %%
# по матрице корреляций можно сделать вывод о том, что чем больше у страны ВВП и, соответственно, социальная поддержка,
# а также чем больше ожидаемая продолжительность жизни, тем более население удовлетворено жизнью.

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? При проецировании данных на эту прямую разброс данных максимален?

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()

ladder = data['Ladder']
generosity = data['Generosity']
sns.regplot(x=ladder, y=generosity, data=data, fit_reg=True)
plt.xlabel('Степень свободы в стране')
plt.ylabel('Доброта')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()

# %%
# похоже, что данная прямая не является собственным вектором и разброс данных не максимален

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
rng = np.random.RandomState(0)
coin_flips = rng.randint(1, 7, size=10)
sns.distplot(coin_flips)
plt.xlabel('Значения')
plt.ylabel('Количество испытаний')
plt.show()

# %%
# похоже на биномиальное распределение

# %% [markdown]
# Напишите код для моделирования 1000 подбрасываний игрального кубика. Начертите диаграму histogram. Почему график изменился? Как применить центральную предельную теорему?

# %%
rng = np.random.RandomState(0)
coin_flips = rng.randint(1, 7, size=1000)
#sns.distplot(coin_flips)
plt.hist(coin_flips, 20)
plt.xlabel('Значения')
plt.ylabel('Количество испытаний')
plt.show()

# %%
# стремится к равномерному распределению
